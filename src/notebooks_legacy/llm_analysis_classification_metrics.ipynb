# %% [markdown]
# # Import Required Libraries
# This section imports all necessary Python libraries for data analysis, statistics, and plotting. Libraries include pandas, numpy, statsmodels, matplotlib, and plotly.

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from statsmodels.stats.contingency_tables import mcnemar
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # Read the Active Document
# This section would typically read the contents of the currently active file in the editor. In this notebook, you can specify a file path to load your data or script for analysis.

# %%
# Example: Read a CSV or script file (replace with your file path)
# data = pd.read_csv('your_data.csv')
with open('d:/Research/llm_summarization/scripts_notebooks/llm_analysis_classification_metrics.py', 'r', encoding='utf-8') as f:
    script_content = f.read()

# %% [markdown]
# # Display the Source Code
# This section prints the contents of the active document (the script) for review or further analysis.

# %%
# Print the script content (first 40 lines for brevity)
print('\n'.join(script_content.splitlines()[:40]))

# %% [markdown]
# # Run Unit Tests in the Active Document
# This section demonstrates how to run unit tests (if present) in the active document using subprocess. Results are captured for display.

# %%
import subprocess
# Example: Run pytest or unittest on the script (if tests are present)
try:
    result = subprocess.run(["pytest", "d:/Research/llm_summarization/scripts_notebooks/llm_analysis_classification_metrics.py"], capture_output=True, text=True)
    test_output = result.stdout + '\n' + result.stderr
except Exception as e:
    test_output = f"Test run failed: {e}"

# %% [markdown]
# # Show Output in Output Pane
# This section displays the results of running the code or tests, simulating an output pane within the notebook.

# %%
# Display the test output (if any)
print(test_output)

# %% [markdown]
# # Open Integrated Terminal and List Files
# This section demonstrates how to use subprocess to simulate opening a terminal and listing files in the current directory.

# %%
# List files in the current directory using subprocess
import os
try:
    if os.name == 'nt':
        result = subprocess.run(['dir'], shell=True, capture_output=True, text=True)
    else:
        result = subprocess.run(['ls', '-l'], capture_output=True, text=True)
    print(result.stdout)
except Exception as e:
    print(f'Failed to list files: {e}')
